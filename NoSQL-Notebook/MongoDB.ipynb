# %%
from IPython.core.display import HTML
def css_styling():   
    styles = open("styles/custom.css", "r").read() 
    return HTML(styles)

# %% [markdown]
# # 1 Introduction to MongoDB
# <small>This introduction is partially inspired on the notes of Alberto Negron's [blog](http://altons.github.io/python/2013/01/21/gentle-introduction-to-mongodb-using-pymongo/)</small>

# %% [markdown]
# MongoDB is a document-oriented database, part of the NoSQL family of database systems. MongoDB stores structured data as JSON-like structures. From a pythonic point of view it is like storing dictionary data structures. One of its main feature is its schema-less feature, i.e. it supports dynamic schemas. A schema in a relational database informally refer to the structure of the data it stores, i.e. what kind of data, which tables, which relations, etc.

# %% [markdown]
# ## Connecting with a MongoDB on the cloud
#
# + First, create an account in [https://cloud.mongodb.com/](https://cloud.mongodb.com/)
# + Build a free cluster instance of 0,5Gb
# + Create a Dabase User under Database Access, and connect to it following next code
# + Install pymongo + dnspython
#
# `pip install "pymongo[srv]"`

# %%
import pymongo
try:
    #create a credentials.txt file in this folder:
    #first line: Database username (not account username)
    #second line: Database username password (not account password)
    #third line: Databse url with port (you can find it in the cloud dashboard)
    #fourth lin: Database name
    if 'conn' in globals():
        conn.close()
        print("Closing")
    
    with open("credentials.txt", 'r') as f:
        [name,password,url,dbname]=f.read().splitlines()
    conn=pymongo.MongoClient("mongodb+srv://{}:{}@{}".format(name,password,url))
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
conn
db = conn[dbname]
db
# Out:
# Connected successfully!!!
# Database(MongoClient(host=['cluster0-shard-00-01.vu6wd.mongodb.net:27017', 'cluster0-shard-00-02.vu6wd.mongodb.net:27017', 'cluster0-shard-00-00.vu6wd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-7w0hla-shard-0', ssl=True), 'cluster0')

# %% [markdown]
# You can check your mongoDB database in this website:
# [https://cloud.mongodb.com/](https://cloud.mongodb.com/)

# %% [markdown]
# ### Connecting with a MongoDB database in localhost

# %% [markdown]
# First of all let us configure the MongoDB system.
#
# + Download mongoDB.
#
# https://www.mongodb.com/download-center/community
#
# + Create data directory:
#
# `sudo mkdir -p /data/db`
# + Check that the server works
#
# `sudo ./mongod --nojournal &`
#
# + Check the connection to the server:
#
# in another terminal write `mongo` , check that it does not raise any error and exit the console.
# + Close the mongo daemon (mongod).
#         You may have to kill mongod with
#
# `killall mongod`
#
#         and remove the lock on the daemon,
# `rm /data/db/mongod.lock`
#
# + Let us configure a little the data base by configuring the path of the data storage and log files. Create a [mongo.conf](./mongo.conf) file such as the one provided  and start the server using the following command:
#
# `mongod --config=./mongo.conf --nojournal &`
#
# + Install pymongo
#
# `pip install pymongo`

# %% [markdown]
# import pymongo
#
# # Connection to Mongo DB
# try:
#     conn=pymongo.MongoClient()
#     print ("Connected successfully!!!")
# except pymongo.errors.ConnectionFailure as e:
#     print ("Could not connect to MongoDB: %s" % e)
# conn

# %% [markdown]
# ## Accessing to / Creating database
#
# We can **create** or **access to** a database using attribute access <span style = "font-family:Courier;"> db = conn.name_db</span> or dictionary acces <span style = "font-family:Courier;"> db = conn[name_db]</span>.

# %%
#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
db = conn['ADS']
print (db)
conn.list_database_names()
#Empty databases do not show!
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.vu6wd.mongodb.net:27017', 'cluster0-shard-00-02.vu6wd.mongodb.net:27017', 'cluster0-shard-00-00.vu6wd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-7w0hla-shard-0', ssl=True), 'ADS')
# ['ADS', 'admin', 'local']

# %% [markdown]
# A database stores a **collection**. A collection is a group of documents stored in MongoDB, and can be thought of as the equivalent of a table in a relational database. Getting a collection in PyMongo works the same as getting a database:

# %%
collection = db.edu
db.list_collection_names()
#Empty collections do not show!
# Out:
# ['edu']

# %% [markdown]
# MongoDB stores structured data as JSON-like documents, using dynamic schemas (called BSON), rather than predefined schemas. An element of data is called a document, and documents are stored in collections. One collection may have any number of documents.
#
# Compared to relational databases, we could say collections are like tables, and documents are like records. But there is one big difference: every record in a table has the same fields (with, usually, differing values) in the same order, while each document in a collection can have completely different fields from the other documents.
#
# All you really need to know when you're using Python, however, is that documents are Python dictionaries that can have strings as keys and can contain various primitive types (int, float,unicode, datetime) as well as other documents (Python dicts) and arrays (Python lists).
#
# To insert some data into MongoDB, all we need to do is create a dict and call .insert() on the collection object. Let us exemplify this process by getting some DatFrame and storing it in the collection.

# %%
import pandas as pd
df = pd.read_csv('./educ_figdp_1_Data.csv',na_values=':')
df.head(5)
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...    NaN                NaN
# 1  Total public expenditure on education as % of ...    NaN                NaN
# 2  Total public expenditure on education as % of ...   5.00                  e
# 3  Total public expenditure on education as % of ...   5.03                  e
# 4  Total public expenditure on education as % of ...   4.95                  e

# %%
df.to_dict("records")
# Out:
# [{'TIME': 2000,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2001,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.99,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2001,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.86,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.01,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.81,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.97,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.99,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.02,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.0,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.94,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.4,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.04,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.44,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.93,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.32,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.2,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.08,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.42,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.05,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.28,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.33,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.3,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.97,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.81,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.68,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.45,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.49,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.57,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.35,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.73,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.71,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.5,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.57,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2003,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.56,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2004,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2005,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.04,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.52,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.83,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.6,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.41,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.37,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.77,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.02,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.45,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.22,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.58,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.14,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.13,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.71,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.63,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.81,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.14,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Lithuania',
# ...
#  {'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.53,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.48,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.44,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.4,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.35,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2001,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.39,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.21,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 2.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.45,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.48,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2007,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.76,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.73,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.2,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.99,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.31,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.3,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.19,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.85,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.8,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.62,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.61,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.89,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.06,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.22,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.42,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.3,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.18,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.1,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %%
#insert documents in the collection
collection.insert_many(df.to_dict("records"))

# %%
#Check that we have a non empty collection.
db.list_collection_names()
# Out:
# ['edu']

# %% [markdown]
# To recap, we have databases containing collections. A collection is made up of documents. Each document is made up of fields.

# %% [markdown]
# ### Retrieving data

# %%
collection.find_one() #Returns first document in the collection
# Out:
# {'_id': ObjectId('6155b7f71f79beda33ac7a0d'),
#  'TIME': 2000,
#  'GEO': 'European Union (28 countries)',
#  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#  'Value': nan,
#  'Flag and Footnotes': nan}

# %% [markdown]
# To get more than a single document as the result of a query we use the find() method. find() returns a Cursor instance, which allows us to iterate over all matching documents.

# %%
collection.find()

# %%
[d for d in collection.find()]
# Out:
# [{'_id': ObjectId('6155b7f71f79beda33ac7a0d'),
#   'TIME': 2000,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a0e'),
#   'TIME': 2001,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a0f'),
#   'TIME': 2002,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a10'),
#   'TIME': 2003,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a11'),
#   'TIME': 2004,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a12'),
#   'TIME': 2005,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a13'),
#   'TIME': 2006,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a14'),
#   'TIME': 2007,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a15'),
#   'TIME': 2008,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a16'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a17'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a18'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a19'),
#   'TIME': 2000,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a1a'),
#   'TIME': 2001,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.99,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a1b'),
#   'TIME': 2002,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a1c'),
#   'TIME': 2003,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a1d'),
#   'TIME': 2004,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a1e'),
#   'TIME': 2005,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a1f'),
#   'TIME': 2006,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a20'),
#   'TIME': 2007,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a21'),
#   'TIME': 2008,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a22'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a23'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a24'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a25'),
#   'TIME': 2000,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a26'),
#   'TIME': 2001,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a27'),
#   'TIME': 2002,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a28'),
#   'TIME': 2003,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a29'),
#   'TIME': 2004,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2a'),
#   'TIME': 2005,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2b'),
#   'TIME': 2006,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2c'),
#   'TIME': 2007,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2d'),
#   'TIME': 2008,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2e'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2f'),
#   'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a30'),
#   'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a31'),
#   'TIME': 2000,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a32'),
#   'TIME': 2001,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a33'),
#   'TIME': 2002,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a34'),
#   'TIME': 2003,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a35'),
#   'TIME': 2004,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a36'),
#   'TIME': 2005,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a37'),
#   'TIME': 2006,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a38'),
#   'TIME': 2007,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a39'),
#   'TIME': 2008,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3a'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3b'),
#   'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3c'),
#   'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3d'),
#   'TIME': 2000,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3e'),
#   'TIME': 2001,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3f'),
#   'TIME': 2002,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.86,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a40'),
#   'TIME': 2003,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a41'),
#   'TIME': 2004,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a42'),
#   'TIME': 2005,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a43'),
#   'TIME': 2006,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a44'),
#   'TIME': 2007,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a45'),
#   'TIME': 2008,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a46'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a47'),
#   'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a48'),
#   'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a49'),
#   'TIME': 2000,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a4a'),
#   'TIME': 2001,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a4b'),
#   'TIME': 2002,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.01,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a4c'),
#   'TIME': 2003,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a4d'),
#   'TIME': 2004,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a4e'),
#   'TIME': 2005,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a4f'),
#   'TIME': 2006,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a50'),
#   'TIME': 2007,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.81,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a51'),
#   'TIME': 2008,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a52'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a53'),
#   'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a54'),
#   'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a55'),
#   'TIME': 2000,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a56'),
#   'TIME': 2001,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.97,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a57'),
#   'TIME': 2002,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a58'),
#   'TIME': 2003,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a59'),
#   'TIME': 2004,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5a'),
#   'TIME': 2005,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5b'),
#   'TIME': 2006,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5c'),
#   'TIME': 2007,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5d'),
#   'TIME': 2008,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5e'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5f'),
#   'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a60'),
#   'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a61'),
#   'TIME': 2000,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a62'),
#   'TIME': 2001,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.99,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a63'),
#   'TIME': 2002,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a64'),
#   'TIME': 2003,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.02,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a65'),
#   'TIME': 2004,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a66'),
#   'TIME': 2005,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a67'),
#   'TIME': 2006,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a68'),
#   'TIME': 2007,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.0,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a69'),
#   'TIME': 2008,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6a'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6b'),
#   'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6c'),
#   'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6d'),
#   'TIME': 2000,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6e'),
#   'TIME': 2001,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6f'),
#   'TIME': 2002,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a70'),
#   'TIME': 2003,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a71'),
#   'TIME': 2004,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.4,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a72'),
#   'TIME': 2005,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a73'),
#   'TIME': 2006,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.04,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a74'),
#   'TIME': 2007,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a75'),
#   'TIME': 2008,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.44,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a76'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a77'),
#   'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a78'),
#   'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a79'),
#   'TIME': 2000,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a7a'),
#   'TIME': 2001,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a7b'),
#   'TIME': 2002,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a7c'),
#   'TIME': 2003,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a7d'),
#   'TIME': 2004,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.2,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a7e'),
#   'TIME': 2005,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a7f'),
#   'TIME': 2006,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.42,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a80'),
#   'TIME': 2007,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.05,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a81'),
#   'TIME': 2008,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a82'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a83'),
#   'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a84'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a85'),
#   'TIME': 2000,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.28,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a86'),
#   'TIME': 2001,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a87'),
#   'TIME': 2002,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a88'),
#   'TIME': 2003,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.33,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a89'),
#   'TIME': 2004,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8a'),
#   'TIME': 2005,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.3,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8b'),
#   'TIME': 2006,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.97,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8c'),
#   'TIME': 2007,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8d'),
#   'TIME': 2008,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.68,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8e'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8f'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a90'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a91'),
#   'TIME': 2000,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.45,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a92'),
#   'TIME': 2001,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a93'),
#   'TIME': 2002,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a94'),
#   'TIME': 2003,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a95'),
#   'TIME': 2004,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a96'),
#   'TIME': 2005,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a97'),
#   'TIME': 2006,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a98'),
#   'TIME': 2007,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.49,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a99'),
#   'TIME': 2008,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9a'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9b'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9c'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9d'),
#   'TIME': 2000,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.57,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9e'),
#   'TIME': 2001,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9f'),
#   'TIME': 2002,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa0'),
#   'TIME': 2003,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa1'),
#   'TIME': 2004,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa2'),
#   'TIME': 2005,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa3'),
#   'TIME': 2006,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa4'),
#   'TIME': 2007,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa5'),
#   'TIME': 2008,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa6'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa7'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa8'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa9'),
#   'TIME': 2000,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aaa'),
#   'TIME': 2001,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aab'),
#   'TIME': 2002,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aac'),
#   'TIME': 2003,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.35,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aad'),
#   'TIME': 2004,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aae'),
#   'TIME': 2005,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aaf'),
#   'TIME': 2006,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.73,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab0'),
#   'TIME': 2007,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab1'),
#   'TIME': 2008,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab2'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab3'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab4'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab5'),
#   'TIME': 2000,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.71,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab6'),
#   'TIME': 2001,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.5,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab7'),
#   'TIME': 2002,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.57,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab8'),
#   'TIME': 2003,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.56,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab9'),
#   'TIME': 2004,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aba'),
#   'TIME': 2005,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7abb'),
#   'TIME': 2006,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7abc'),
#   'TIME': 2007,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7abd'),
#   'TIME': 2008,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7abe'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7abf'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac0'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac1'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac2'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac3'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac4'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac5'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac6'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac7'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac8'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac9'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aca'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7acb'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7acc'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7acd'),
#   'TIME': 2000,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.04,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ace'),
#   'TIME': 2001,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7acf'),
#   'TIME': 2002,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ad0'),
# ...
#  {'_id': ObjectId('6156ecc08e7ae49eda599bcc'),
#   'TIME': 2004,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bcd'),
#   'TIME': 2005,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bce'),
#   'TIME': 2006,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bcf'),
#   'TIME': 2007,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd0'),
#   'TIME': 2008,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd1'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd2'),
#   'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd3'),
#   'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd4'),
#   'TIME': 2000,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd5'),
#   'TIME': 2001,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.39,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd6'),
#   'TIME': 2002,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd7'),
#   'TIME': 2003,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd8'),
#   'TIME': 2004,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd9'),
#   'TIME': 2005,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.21,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bda'),
#   'TIME': 2006,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bdb'),
#   'TIME': 2007,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bdc'),
#   'TIME': 2008,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bdd'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bde'),
#   'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bdf'),
#   'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be0'),
#   'TIME': 2000,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 2.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be1'),
#   'TIME': 2001,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be2'),
#   'TIME': 2002,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be3'),
#   'TIME': 2003,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.45,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be4'),
#   'TIME': 2004,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be5'),
#   'TIME': 2005,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.48,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be6'),
#   'TIME': 2006,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be7'),
#   'TIME': 2007,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be8'),
#   'TIME': 2008,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be9'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bea'),
#   'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599beb'),
#   'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bec'),
#   'TIME': 2000,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bed'),
#   'TIME': 2001,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bee'),
#   'TIME': 2002,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.76,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bef'),
#   'TIME': 2003,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf0'),
#   'TIME': 2004,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf1'),
#   'TIME': 2005,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.73,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf2'),
#   'TIME': 2006,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf3'),
#   'TIME': 2007,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf4'),
#   'TIME': 2008,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.2,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf5'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf6'),
#   'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf7'),
#   'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf8'),
#   'TIME': 2000,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf9'),
#   'TIME': 2001,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.99,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bfa'),
#   'TIME': 2002,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.31,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bfb'),
#   'TIME': 2003,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.3,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bfc'),
#   'TIME': 2004,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.19,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bfd'),
#   'TIME': 2005,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.85,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bfe'),
#   'TIME': 2006,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.8,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bff'),
#   'TIME': 2007,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c00'),
#   'TIME': 2008,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.61,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c01'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c02'),
#   'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c03'),
#   'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c04'),
#   'TIME': 2000,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.89,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c05'),
#   'TIME': 2001,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c06'),
#   'TIME': 2002,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.22,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c07'),
#   'TIME': 2003,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c08'),
#   'TIME': 2004,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.42,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c09'),
#   'TIME': 2005,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.3,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0a'),
#   'TIME': 2006,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.18,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0b'),
#   'TIME': 2007,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0c'),
#   'TIME': 2008,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0d'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0e'),
#   'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0f'),
#   'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %% [markdown]
# If we just want to know how many documents match a query we can perform a count() operation instead of a full query. We can get a count of all of the documents in a collection:

# %%
collection.count_documents({})
# Out:
# 768

# %% [markdown]
# ### Basic queries

# %% [markdown]
# Querying in pymongo uses .find()

# %%
[d for d in collection.find({"TIME":2009})]
# Out:
# [{'_id': ObjectId('6155b7f71f79beda33ac7a16'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a22'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2e'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3a'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a46'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a52'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5e'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6a'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a76'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a82'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8e'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9a'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa6'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab2'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7abe'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aca'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ad6'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ae2'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aee'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7afa'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b06'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b12'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b1e'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b2a'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b36'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b42'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b4e'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b5a'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b66'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b72'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b7e'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b8a'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599a99'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aa5'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ab1'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599abd'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ac9'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ad5'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ae1'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aed'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599af9'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b05'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b11'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b1d'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b29'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b35'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b41'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4d'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b59'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b65'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b71'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b7d'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b89'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b95'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ba1'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bad'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bb9'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bc5'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd1'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bdd'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be9'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf5'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c01'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0d'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan}]

# %% [markdown]
# Observe that it finds exact matches (including data type)

# %%
[d for d in collection.find({"TIME":"2009"})]
# Out:
# []

# %%
[d for d in collection.find({"GEO":"Spain"})]
# Out:
# [{'_id': ObjectId('6155b7f71f79beda33ac7ac1'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac2'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac3'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac4'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac5'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac6'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac7'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac8'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac9'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aca'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7acb'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7acc'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b44'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b45'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b46'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b47'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b48'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b49'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4a'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4b'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4c'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4d'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4e'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4f'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan}]

# %%
[d for d in collection.find({"GEO":"SPAIN"})]
# Out:
# []

# %% [markdown]
# Operations include *gt* (greater than), *gte* (greater than equal), *lt* (lesser than), *lte* (lesser than equal), *ne* (not equal), *nin* (not in a list), *regex* (regular expression), *exists*, *not*, *or*, *and*, etc. Let us see some examples:

# %%
[d for d in collection.find({"TIME":{"$gte":2009}})]
# Out:
# [{'_id': ObjectId('6155b7f71f79beda33ac7a16'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a17'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a18'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a22'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a23'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a24'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2e'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a2f'),
#   'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a30'),
#   'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3a'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3b'),
#   'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a3c'),
#   'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a46'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a47'),
#   'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a48'),
#   'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a52'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a53'),
#   'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a54'),
#   'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5e'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a5f'),
#   'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a60'),
#   'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6a'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6b'),
#   'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a6c'),
#   'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a76'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a77'),
#   'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a78'),
#   'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a82'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a83'),
#   'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a84'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8e'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a8f'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a90'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9a'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9b'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7a9c'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa6'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa7'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aa8'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab2'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab3'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ab4'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7abe'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7abf'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ac0'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aca'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7acb'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7acc'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ad6'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ad7'),
#   'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ad8'),
#   'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ae2'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ae3'),
#   'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7ae4'),
#   'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aee'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7aef'),
#   'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7af0'),
#   'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7afa'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7afb'),
#   'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7afc'),
#   'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b06'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b07'),
#   'TIME': 2010,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b08'),
#   'TIME': 2011,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b12'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b13'),
#   'TIME': 2010,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b14'),
#   'TIME': 2011,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b1e'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b1f'),
#   'TIME': 2010,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b20'),
#   'TIME': 2011,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.71,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b2a'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b2b'),
#   'TIME': 2010,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b2c'),
#   'TIME': 2011,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b36'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b37'),
#   'TIME': 2010,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b38'),
#   'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b42'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b43'),
#   'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b44'),
#   'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b4e'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b4f'),
#   'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b50'),
#   'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b5a'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b5b'),
#   'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b5c'),
#   'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b66'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b67'),
#   'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b68'),
#   'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b72'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b73'),
#   'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b74'),
#   'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b7e'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b7f'),
#   'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b80'),
#   'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b8a'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b8b'),
#   'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6155b7f71f79beda33ac7b8c'),
#   'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599a99'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599a9a'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599a9b'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aa5'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aa6'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aa7'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ab1'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ab2'),
#   'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ab3'),
#   'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599abd'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599abe'),
#   'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599abf'),
#   'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ac9'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aca'),
#   'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599acb'),
#   'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ad5'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ad6'),
#   'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ad7'),
#   'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ae1'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ae2'),
#   'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ae3'),
#   'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aed'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aee'),
#   'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599aef'),
#   'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599af9'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599afa'),
#   'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599afb'),
#   'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b05'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b06'),
#   'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b07'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b11'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b12'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b13'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b1d'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b1e'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b1f'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b29'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b2a'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b2b'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b35'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b36'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b37'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b41'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b42'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b43'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4d'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4e'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b4f'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b59'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b5a'),
#   'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b5b'),
#   'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b65'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b66'),
#   'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b67'),
#   'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b71'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b72'),
#   'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b73'),
#   'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b7d'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b7e'),
#   'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b7f'),
#   'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b89'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b8a'),
#   'TIME': 2010,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b8b'),
#   'TIME': 2011,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b95'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b96'),
#   'TIME': 2010,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599b97'),
#   'TIME': 2011,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ba1'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ba2'),
#   'TIME': 2010,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599ba3'),
#   'TIME': 2011,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.71,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bad'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bae'),
#   'TIME': 2010,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599baf'),
#   'TIME': 2011,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bb9'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bba'),
#   'TIME': 2010,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bbb'),
#   'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bc5'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bc6'),
#   'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bc7'),
#   'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd1'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd2'),
#   'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bd3'),
#   'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bdd'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bde'),
#   'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bdf'),
#   'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599be9'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bea'),
#   'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599beb'),
#   'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf5'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf6'),
#   'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599bf7'),
#   'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c01'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c02'),
#   'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c03'),
#   'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0d'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0e'),
#   'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6156ecc08e7ae49eda599c0f'),
#   'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %%
substring = r'Euro'
reg = substring
[(i["GEO"]) for i in collection.find({"GEO":{"$regex":reg}})]
# Out:
# ['European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)']

# %%
for item in collection.find({"GEO":{"$regex":reg}}):
     print (item['GEO'])
# Out:
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)

# %% [markdown]
# ### Update

# %% [markdown]
# In this section, several methods for updating and deleting documents are reveiwed:
#
# + Replace. This method finds the documents defined by query and **replaces** it by the new document.

# %%
#Insert One new Document
import numpy as np
doc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': np.nan}
collection.insert_one(doc)

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6156ecc38e7ae49eda599c10'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': nan}

# %%
#Replace first occurence
newdoc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': 15}
collection.replace_one({'GEO':"Catalunya"},newdoc)

for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6156ecc38e7ae49eda599c10'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 15}

# %% [markdown]
# If we don't want to write again all the document and just put the field that we want to change then we have to use **update_one** and adding a sub-command.  Let us check some of them:

# %% [markdown]
# + Sub-command **Set**:
#
# This statement updates in the document in collection where field matches value1 by replacing the value of the field field1 with value2. This operator will add the specified field or fields if they do not exist in this document or replace the existing value of the specified field(s) if they already exist.
#
# An upsert eliminates the need to perform a separate database call to check for the existence of a record before performing either an update or an insert operation. Typically update operations update existing documents, but in MongoDB, the update_one() operation can accept an upsert option as an argument. Upserts are a hybrid operation that use the query argument to determine the write operation:
#
# If the query matches an existing document(s), the upsert performs an update.
# If the query matches no document in the collection, the upsert inserts a single document.

# %%
#Update first occurrence
collection.update_one({'GEO':"Catalunya"},{"$set":{"Value":12}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6156ecc38e7ae49eda599c10'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 12}

# %% [markdown]
# By default, if the filter doesn't return any document, nothing is inserted to database. If you want to insert it, then set the upsert flag to `True`

# %%
collection.update_one({'GEO':"Andorra"},{"$set":{"Value":12}},upsert = True)
for doc in collection.find({'GEO':"Andorra"}):
    print (doc)
# Out:
# {'_id': ObjectId('6156ecc3a387a1d162c74182'), 'GEO': 'Andorra', 'Value': 12}

# %% [markdown]
# + Sub-commnad **Unset**:
#
# The unset operator deletes a particular field. If documents match the initial query but do not have the field specified in the unset operation, there the statement has no effect on the document.

# %%
collection.update_one({'GEO':"Catalunya"},{"$unset":{"Flag and Footnotes":""}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6156ecc38e7ae49eda599c10'), 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 12}

# %% [markdown]
# ### Delete operations

# %% [markdown]
# We can remove elements by simply:

# %%
collection.delete_one({"GEO":"Andorra"})

# %%
for doc in collection.find({"GEO":"Andorra"}):
    print (doc)

# %% [markdown]
# And remove a collection by:

# %%
db.list_collection_names()
# Out:
# ['edu']

# %%
db.drop_collection("edu")
db.list_collection_names()
# Out:
# []

# %% [markdown]
# And remove a database by:

# %%
conn.list_database_names()
# Out:
# ['admin', 'local']

# %%
conn.drop_database('ads')
conn.list_database_names()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /tmp/ipykernel_37188/1804286392.py in <module>
# ----> 1 conn.drop_database('ads')
#       2 conn.list_database_names()
#
# ~/PythonEnvironments/data-science-3.8/lib/python3.8/site-packages/pymongo/mongo_client.py in drop_database(self, name_or_database, session)
#    2091         self._purge_index(name)
#    2092         with self._socket_for_writes(session) as sock_info:
# -> 2093             self[name]._command(
#    2094                 sock_info,
#    2095                 "dropDatabase",
#
# ~/PythonEnvironments/data-science-3.8/lib/python3.8/site-packages/pymongo/database.py in _command(self, sock_info, command, secondary_ok, value, check, allowable_errors, read_preference, codec_options, write_concern, parse_write_concern_error, session, **kwargs)
#     633         command.update(kwargs)
#     634         with self.__client._tmp_session(session) as s:
# --> 635             return sock_info.command(
#     636                 self.__name,
#     637                 command,
#
# ~/PythonEnvironments/data-science-3.8/lib/python3.8/site-packages/pymongo/pool.py in command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708             self._raise_if_not_writable(unacknowledged)
#     709         try:
# --> 710             return command(self, dbname, spec, secondary_ok,
#     711                            self.is_mongos, read_preference, codec_options,
#     712                            session, client, check, allowable_errors,
#
# ~/PythonEnvironments/data-science-3.8/lib/python3.8/site-packages/pymongo/network.py in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156                 client._process_response(response_doc, session)
#     157             if check:
# --> 158                 helpers._check_command_response(
#     159                     response_doc, sock_info.max_wire_version, allowable_errors,
#     160                     parse_write_concern_error=parse_write_concern_error)
#
# ~/PythonEnvironments/data-science-3.8/lib/python3.8/site-packages/pymongo/helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     165         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     166
# --> 167     raise OperationFailure(errmsg, code, response, max_wire_version)
#     168
#     169
#
# OperationFailure: user is not allowed to do action [dropDatabase] on [ads.], full error: {'ok': 0, 'errmsg': 'user is not allowed to do action [dropDatabase] on [ads.]', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# And finally close the connection with the database.

# %%
conn.close()
